# %% [markdown]
# # Impacto da Covid-19 em Portugal #

# %% [markdown]
# > Neste notebook vão estar presentes algumas esttísticas sobre o impacto da covid-19 em Portugal, tanto ao nível das mortes, como impacto no turismo, desemprego entre outros.

# %% [markdown]
# * ### Impacto no número de Mortes ###

# %% [markdown]
# > Seguidamente vai ser comparado o número de mortes em Portugal em 2019 e o número de mortes em 2020.
#
# >Os dados relativos ao [Número total de mortes em cada ano](https://github.com/DianaA82332/Epidemiologia/blob/master/Trabalho_final/mortalidade_total.csv), às [Causas de Morte no ano de 2019](https://github.com/DianaA82332/Epidemiologia/blob/master/Trabalho_final/tipo_morte2019.csv) e às [Causas de morte no ano de 2020](https://github.com/DianaA82332/Epidemiologia/blob/master/Trabalho_final/tipo_morte2020.csv) foram retirados do [Sistema de Informação de Certificados de Óbito (SICO](https://evm.min-saude.pt/).

# %%
import pandas as pd
import numpy as np
dados=pd.read_csv("/Users/dianamartins/Documents/GitHub/Epidemiologia/Trabalho_final/mortalidade_total.csv")
dados.head()
# Out:
#      Data   2009   2010   2011  2012   2013   2014   2015  2016   2017   2018  \
# 0  Jan-01  423.0  318.0  384.0   379  339.0  375.0  407.0   366  475.0  414.0
# 1  Jan-02  435.0  364.0  357.0   357  343.0  394.0  413.0   314  578.0  418.0
# 2  Jan-03  416.0  357.0  370.0   356  352.0  399.0  416.0   339  479.0  450.0
# 3  Jan-04  380.0  322.0  350.0   362  321.0  327.0  466.0   348  501.0  425.0
# 4  Jan-05  446.0  334.0  368.0   354  342.0  359.0  452.0   329  493.0  434.0
#
#     2019   2020
# 0  371.0  376.0
# 1  386.0  381.0
# 2  367.0  374.0
# 3  371.0  364.0
# 4  367.0  333.0

# %%
import plotly.offline as py
import plotly.graph_objs as go
py.init_notebook_mode(connected=True)

Ano_2019 = go.Bar(x = dados['Data'],
                y = dados['2019'],
                name = 'Ano 2019')
Ano_2020 = go.Bar(x = dados['Data'],
                y = dados['2020'],
                name = 'Ano 2020')
dados = [Ano_2019, Ano_2020]
py.iplot(dados)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="866d8cb1-9dfa-43f4-b6a3-065199938892" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("866d8cb1-9dfa-43f4-b6a3-065199938892")) {
#                     Plotly.newPlot(
#                         '866d8cb1-9dfa-43f4-b6a3-065199938892',
#                         [{"name": "Ano 2019", "type": "bar", "x": ["Jan-01", "Jan-02", "Jan-03", "Jan-04", "Jan-05", "Jan-06", "Jan-07", "Jan-08", "Jan-09", "Jan-10", "Jan-11", "Jan-12", "Jan-13", "Jan-14", "Jan-15", "Jan-16", "Jan-17", "Jan-18", "Jan-19", "Jan-20", "Jan-21", "Jan-22", "Jan-23", "Jan-24", "Jan-25", "Jan-26", "Jan-27", "Jan-28", "Jan-29", "Jan-30", "Jan-31", "Fev-01", "Fev-02", "Fev-03", "Fev-04", "Fev-05", "Fev-06", "Fev-07", "Fev-08", "Fev-09", "Fev-10", "Fev-11", "Fev-12", "Fev-13", "Fev-14", "Fev-15", "Fev-16", "Fev-17", "Fev-18", "Fev-19", "Fev-20", "Fev-21", "Fev-22", "Fev-23", "Fev-24", "Fev-25", "Fev-26", "Fev-27", "Fev-28", "Fev-29", "Mar-01", "Mar-02", "Mar-03", "Mar-04", "Mar-05", "Mar-06", "Mar-07", "Mar-08", "Mar-09", "Mar-10", "Mar-11", "Mar-12", "Mar-13", "Mar-14", "Mar-15", "Mar-16", "Mar-17", "Mar-18", "Mar-19", "Mar-20", "Mar-21", "Mar-22", "Mar-23", "Mar-24", "Mar-25", "Mar-26", "Mar-27", "Mar-28", "Mar-29", "Mar-30", "Mar-31", "Abr-01", "Abr-02", "Abr-03", "Abr-04", "Abr-05", "Abr-06", "Abr-07", "Abr-08", "Abr-09", "Abr-10", "Abr-11", "Abr-12", "Abr-13", "Abr-14", "Abr-15", "Abr-16", "Abr-17", "Abr-18", "Abr-19", "Abr-20", "Abr-21", "Abr-22", "Abr-23", "Abr-24", "Abr-25", "Abr-26", "Abr-27", "Abr-28", "Abr-29", "Abr-30", "Mai-01", "Mai-02", "Mai-03", "Mai-04", "Mai-05", "Mai-06", "Mai-07", "Mai-08", "Mai-09", "Mai-10", "Mai-11", "Mai-12", "Mai-13", "Mai-14", "Mai-15", "Mai-16", "Mai-17", "Mai-18", "Mai-19", "Mai-20", "Mai-21", "Mai-22", "Mai-23", "Mai-24", "Mai-25", "Mai-26", "Mai-27", "Mai-28", "Mai-29", "Mai-30", "Mai-31", "Jun-01", "Jun-02", "Jun-03", "Jun-04", "Jun-05", "Jun-06", "Jun-07", "Jun-08", "Jun-09", "Jun-10", "Jun-11", "Jun-12", "Jun-13", "Jun-14", "Jun-15", "Jun-16", "Jun-17", "Jun-18", "Jun-19", "Jun-20", "Jun-21", "Jun-22", "Jun-23", "Jun-24", "Jun-25", "Jun-26", "Jun-27", "Jun-28", "Jun-29", "Jun-30", "Jul-01", "Jul-02", "Jul-03", "Jul-04", "Jul-05", "Jul-06", "Jul-07", "Jul-08", "Jul-09", "Jul-10", "Jul-11", "Jul-12", "Jul-13", "Jul-14", "Jul-15", "Jul-16", "Jul-17", "Jul-18", "Jul-19", "Jul-20", "Jul-21", "Jul-22", "Jul-23", "Jul-24", "Jul-25", "Jul-26", "Jul-27", "Jul-28", "Jul-29", "Jul-30", "Jul-31", "Ago-01", "Ago-02", "Ago-03", "Ago-04", "Ago-05", "Ago-06", "Ago-07", "Ago-08", "Ago-09", "Ago-10", "Ago-11", "Ago-12", "Ago-13", "Ago-14", "Ago-15", "Ago-16", "Ago-17", "Ago-18", "Ago-19", "Ago-20", "Ago-21", "Ago-22", "Ago-23", "Ago-24", "Ago-25", "Ago-26", "Ago-27", "Ago-28", "Ago-29", "Ago-30", "Ago-31", "Set-01", "Set-02", "Set-03", "Set-04", "Set-05", "Set-06", "Set-07", "Set-08", "Set-09", "Set-10", "Set-11", "Set-12", "Set-13", "Set-14", "Set-15", "Set-16", "Set-17", "Set-18", "Set-19", "Set-20", "Set-21", "Set-22", "Set-23", "Set-24", "Set-25", "Set-26", "Set-27", "Set-28", "Set-29", "Set-30", "Out-01", "Out-02", "Out-03", "Out-04", "Out-05", "Out-06", "Out-07", "Out-08", "Out-09", "Out-10", "Out-11", "Out-12", "Out-13", "Out-14", "Out-15", "Out-16", "Out-17", "Out-18", "Out-19", "Out-20", "Out-21", "Out-22", "Out-23", "Out-24", "Out-25", "Out-26", "Out-27", "Out-28", "Out-29", "Out-30", "Out-31", "Nov-01", "Nov-02", "Nov-03", "Nov-04", "Nov-05", "Nov-06", "Nov-07", "Nov-08", "Nov-09", "Nov-10", "Nov-11", "Nov-12", "Nov-13", "Nov-14", "Nov-15", "Nov-16", "Nov-17", "Nov-18", "Nov-19", "Nov-20", "Nov-21", "Nov-22", "Nov-23", "Nov-24", "Nov-25", "Nov-26", "Nov-27", "Nov-28", "Nov-29", "Nov-30", "Dez-01", "Dez-02", "Dez-03", "Dez-04", "Dez-05", "Dez-06", "Dez-07", "Dez-08", "Dez-09", "Dez-10", "Dez-11", "Dez-12", "Dez-13", "Dez-14", "Dez-15", "Dez-16", "Dez-17", "Dez-18", "Dez-19", "Dez-20", "Dez-21", "Dez-22", "Dez-23", "Dez-24", "Dez-25", "Dez-26", "Dez-27", "Dez-28", "Dez-29", "Dez-30", "Dez-31"], "y": [371.0, 386.0, 367.0, 371.0, 367.0, 409.0, 415.0, 376.0, 417.0, 437.0, 408.0, 431.0, 416.0, 483.0, 414.0, 445.0, 413.0, 415.0, 403.0, 414.0, 408.0, 438.0, 445.0, 457.0, 439.0, 416.0, 433.0, 434.0, 445.0, 425.0, 431.0, 401.0, 398.0, 370.0, 381.0, 415.0, 428.0, 395.0,  ...

# %% [markdown]
# > É importante referir que, desde o início de março e até finais de abril, o número de mortes em 2020 é significativamente mais alto quando comparado com o número de mortes em 2019.

# %% [markdown]
# #### Comparação entre as causas de morte em 2019 e as causas de morte em 2020 ####

# %%
import pandas as pd
import numpy as np
dados=pd.read_csv("/Users/dianamartins/Documents/GitHub/Epidemiologia/Trabalho_final/tipo_morte2019.csv")
dados.head()
# Out:
#   Data (mm-dd)  Morte natural  Causa externa  Sujeito a investigação
# 0       Jan-01            325              2                      44
# 1       Jan-02            343              1                      42
# 2       Jan-03            327              4                      36
# 3       Jan-04            335              4                      32
# 4       Jan-05            321              8                      38

# %% [markdown]
# #### Seleção dos dados importantes ####
#
# > Relativamente ao ano de 2019 foram selecionados os dados até ao dia 28 de maio de 2019

# %%
dados.loc[0:147]
# Out:
#     Data (mm-dd)  Morte natural  Causa externa  Sujeito a investigação
# 0         Jan-01            325              2                      44
# 1         Jan-02            343              1                      42
# 2         Jan-03            327              4                      36
# 3         Jan-04            335              4                      32
# 4         Jan-05            321              8                      38
# ..           ...            ...            ...                     ...
# 143       Mai-24            237              3                      29
# 144       Mai-25            269              3                      28
# 145       Mai-26            262              5                      26
# 146       Mai-27            232              4                      29
# 147       Mai-28            231              8                      27
#
# [148 rows x 4 columns]

# %%
dados2=pd.read_csv("/Users/dianamartins/Documents/GitHub/Epidemiologia/Trabalho_final/tipo_morte2020.csv")
dados2.head()
# Out:
#   Data (mm-dd)  Morte natural  Causa externa  Sujeito a investigação
# 0       Jan-01            328              5                      43
# 1       Jan-02            335              5                      41
# 2       Jan-03            335              3                      36
# 3       Jan-04            312              6                      46
# 4       Jan-05            297              3                      33

# %%
import plotly.offline as py
import plotly.graph_objs as go
py.init_notebook_mode(connected=True)

trace1 = go.Scatter(x = dados.loc[0:147]['Data (mm-dd)'],
                    y = dados.loc[0:147]['Morte natural'],
                    mode = 'lines',
                    name = 'Morte Natural no ano de 2019',
                    line = {'color': '#ee5253',
                            'dash': 'dot'})
# Gráfico de apenas linhas
trace3 = go.Scatter(x = dados.loc[0:147]['Data (mm-dd)'],
                    y = dados.loc[0:147]['Causa externa'],
                    mode = 'lines',
                    name = 'Morte devido a Causa Externa no ano de 2019',
                    line = {'color': '#0d0b0d',
                            'dash': 'dot'})

trace5 = go.Scatter(x = dados.loc[0:147]['Data (mm-dd)'],
                    y = dados.loc[0:147]['Sujeito a investigação'],
                    mode = 'lines',
                    name = 'Morte Sujeita a Investigação no ano de 2019',
                    line = {'color': '#52bdee',
                            'dash': 'dot'})

trace2 = go.Scatter(x = dados2['Data (mm-dd)'],
                    y = dados2['Morte natural'],
                    mode = 'lines',
                    name = 'Morte Natural no ano de 2020',
                    line = {'color': '#eee152',
                            'dash': 'dot'})

trace4 = go.Scatter(x = dados2['Data (mm-dd)'],
                    y = dados2['Causa externa'],
                    mode = 'lines',
                    name = 'Morte devido a Causa Externa no ano de 2020',
                    line = {'color': '#5fee52',
                            'dash': 'dot'})

trace6 = go.Scatter(x = dados2['Data (mm-dd)'],
                    y = dados2['Sujeito a investigação'],
                    mode = 'lines',
                    name = 'Morte Sujeita a Investigação no ano de 2020',
                    line = {'color': '#ee52e4',
                            'dash': 'dot'})

data = [trace1, trace2, trace3, trace4, trace5, trace6]
py.iplot(data)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="08c056a4-064a-4192-bccf-cd8cfebae0ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("08c056a4-064a-4192-bccf-cd8cfebae0ba")) {
#                     Plotly.newPlot(
#                         '08c056a4-064a-4192-bccf-cd8cfebae0ba',
#                         [{"line": {"color": "#ee5253", "dash": "dot"}, "mode": "lines", "name": "Morte Natural no ano de 2019", "type": "scatter", "x": ["Jan-01", "Jan-02", "Jan-03", "Jan-04", "Jan-05", "Jan-06", "Jan-07", "Jan-08", "Jan-09", "Jan-10", "Jan-11", "Jan-12", "Jan-13", "Jan-14", "Jan-15", "Jan-16", "Jan-17", "Jan-18", "Jan-19", "Jan-20", "Jan-21", "Jan-22", "Jan-23", "Jan-24", "Jan-25", "Jan-26", "Jan-27", "Jan-28", "Jan-29", "Jan-30", "Jan-31", "Fev-01", "Fev-02", "Fev-03", "Fev-04", "Fev-05", "Fev-06", "Fev-07", "Fev-08", "Fev-09", "Fev-10", "Fev-11", "Fev-12", "Fev-13", "Fev-14", "Fev-15", "Fev-16", "Fev-17", "Fev-18", "Fev-19", "Fev-20", "Fev-21", "Fev-22", "Fev-23", "Fev-24", "Fev-25", "Fev-26", "Fev-27", "Fev-28", "Mar-01", "Mar-02", "Mar-03", "Mar-04", "Mar-05", "Mar-06", "Mar-07", "Mar-08", "Mar-09", "Mar-10", "Mar-11", "Mar-12", "Mar-13", "Mar-14", "Mar-15", "Mar-16", "Mar-17", "Mar-18", "Mar-19", "Mar-20", "Mar-21", "Mar-22", "Mar-23", "Mar-24", "Mar-25", "Mar-26", "Mar-27", "Mar-28", "Mar-29", "Mar-30", "Mar-31", "Abr-01", "Abr-02", "Abr-03", "Abr-04", "Abr-05", "Abr-06", "Abr-07", "Abr-08", "Abr-09", "Abr-10", "Abr-11", "Abr-12", "Abr-13", "Abr-14", "Abr-15", "Abr-16", "Abr-17", "Abr-18", "Abr-19", "Abr-20", "Abr-21", "Abr-22", "Abr-23", "Abr-24", "Abr-25", "Abr-26", "Abr-27", "Abr-28", "Abr-29", "Abr-30", "Mai-01", "Mai-02", "Mai-03", "Mai-04", "Mai-05", "Mai-06", "Mai-07", "Mai-08", "Mai-09", "Mai-10", "Mai-11", "Mai-12", "Mai-13", "Mai-14", "Mai-15", "Mai-16", "Mai-17", "Mai-18", "Mai-19", "Mai-20", "Mai-21", "Mai-22", "Mai-23", "Mai-24", "Mai-25", "Mai-26", "Mai-27", "Mai-28"], "y": [325, 343, 327, 335, 321, 367, 371, 340, 368, 396, 351, 382, 378, 426, 376, 396, 372, 383, 371, 362, 350, 396, 403, 412, 395, 374, 391, 381, 392, 366, 393, 358, 363, 337, 325, 369, 386, 351, 343, 365, 337, 402, 344, 325, 346, 357, 342, 331, 338, 353, 304, 344, 304, 349, 318, 322, 325, 302, 328, 321, 301, 327, 314, 300, 286, 306, 296, 299, 307, 303, 314, 282, 317, 253, 297, 293, 265, 285, 299, 311, 260, 293, 255, 257, 287, 287, 243, 252, 311, 279, 298, 280, 248, 247, 292, 265, 287, 303, 253, 290, 274, 270, 267, 276, 273, 277, 259, 242, 264, 268, 277, 299, 273, 284, 251, 264, 250, 274, 263, 281, 250, 240, 274, 287, 294, 254, 279, 253, 214, 301, 247, 255, 239, 266, 292, 258, 217, 232, 239, 240, 236, 244, 225, 237, 269, 262, 232, 231]}, {"line": {"color": "#eee152", "dash": "dot"}, "mode": "lines", "name": "Morte Natural no ano de 2020", "type": "scatter", "x": ["Jan-01", "Jan-02", "Jan-03", "Jan-04", "Jan-05", "Jan-06", "Jan-07", "Jan-08", "Jan-09", "Jan-10", "Jan-11", "Jan-12", "Jan-13", "Jan-14", "Jan-15", "Jan-16", "Jan-17", "Jan-18", "Jan-19", "Jan-20", "Jan-21", "Jan-22", "Jan-23", "Jan-24", "Jan-25", "Jan-26", "Jan-27", "Jan-28", "Jan-29", "Jan-30", "Jan-31", "Fev-01", "Fev-02", "Fev-03", "Fev-04", "Fev-05", "Fev-06", "Fev-07", "Fev-08", "Fev-09", "Fev-10", "Fev-11", "Fev-12", "Fev-13", "Fev-14", "Fev-15", "Fev-16", "Fev-17", "Fev-18", "Fev-19", "Fev-20", "Fev-21", "Fev-22", "Fev-23", "Fev-24", "Fev-25", "Fev-26", "Fev-27", "Fev-28", "Fev-29", "Mar-01", "Mar-02", "Mar-03", "Mar-04", "Mar-05", "Mar-06", "Mar-07", "Mar-08", "Mar-09", "Mar-10", "Mar-11", "Mar-12", "Mar-13", "Mar-14", "Mar-15", "Mar-16", "Mar-17", "Mar-18", "Mar-19", "Mar-20", "Mar-21", "Mar-22", "Mar-23", "Mar-24", "Mar-25", "Mar-26", "Mar-27", "Mar-28", "Mar-29", "Mar-30", "Mar-31", "Abr-01", "Abr-02", "Abr-03", "Abr-04", "Abr-05", "Abr-06", "Abr-07", "Abr-08", "Abr-09", "Abr-10", "Abr-11", "Abr-12", "Abr-13", "Abr-14", "Abr-15", "Abr-16", "Abr-17", "Abr-18", "Abr-19", "Abr-20", "Abr-21", "Abr-22", "Abr-23", "Abr-24", "Abr-25", "Abr-26", "Abr-27", "Abr-28", "Abr-29", "Abr-30", "Mai-01", "Mai-02", "Mai-03", "Mai-04", "Mai-05", "Mai-06", "Mai-07", "Mai-08", "Mai-09", "Mai-10", "Mai-11", "Mai-12", "Mai-13", "Mai-14", "Mai-15", "Mai-16", "Mai-17", "Mai-18", "Mai-19", "Mai-20", "Mai-21", "Mai-22", "Mai-23", "Mai-24", "Mai-25", "Mai-26", "Mai-27", "Mai-28"], ...

# %% [markdown]
# > A morte devido ao covid-19 é considerada uma morte natural.
# Verificando o gráfico anterior, o número de mortes devido a causa natural em 2020 foi bastante superior entre o início de março e finais de abril.

# %% [markdown]
# * ### Impacto a nível económico ###

# %% [markdown]
# > Agora vai ser mostrada a taxa de variação do PIB a preços constantes
